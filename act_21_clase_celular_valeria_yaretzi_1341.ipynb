# %% [markdown]
# <a href="https://colab.research.google.com/github/VALERIAMARTINEZ128/act-21-clase-celular-/blob/main/act_21_clase_celular_valeria_yaretzi_1341.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### valeria yaretzi  Lopez NL = 32 Fecha 22/abril/2026
# #### Clase celular
# ![Texto del vínculo](https://raw.githubusercontent.com/VALERIAMARTINEZ128/act-21-clase-celular-/refs/heads/main/infografia.jpeg)

# %%
class Celular:
    def __init__(self, marca, modelo, precio):
        self.marca = marca
        self.modelo = modelo
        self.precio = precio
        self.encendido = False

    def encender(self):
        print(f"El {self.modelo} se ha encendido.")
        self.encendido = True
        print(f"El celular está encendido: {self.encendido}")

    def mostrar_info(self):
        print(f"Celular: {self.marca} {self.modelo}, Precio: ${self.precio}")
# Instanciación
celular1 = Celular("Samsung", "Galaxy S23", 999.99)
celular2 = Celular("Apple", "iPhone 15 Pro", 1199.99)
#llamada a las funciones para cada objeto celular 1 y celular 2
print("celular 1:")
celular1.mostrar_info()
celular1.encender()

print("celular 2:")
celular2.encender()
celular2.mostrar_info()

print("Programa terminado")
print("Creador de Software por valeria yaretzi  Lopez NL = 32")
# Out:
# celular 1:
# Celular: Samsung Galaxy S23, Precio: $999.99
# El Galaxy S23 se ha encendido.
# El celular está encendido: True
# celular 2:
# El iPhone 15 Pro se ha encendido.
# El celular está encendido: True
# Celular: Apple iPhone 15 Pro, Precio: $1199.99
# Programa terminado
# Creador de Software por valeria yaretzi  Lopez NL = 32

# %% [markdown]
# ![Texto del vínculo](https://raw.githubusercontent.com/VALERIAMARTINEZ128/act-21-clase-celular-/refs/heads/main/shapes%20at%2026-04-23%2021.25.59.png)
